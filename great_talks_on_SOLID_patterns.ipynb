# %%
from IPython.display import YouTubeVideo

# %% [markdown]
# A great talk by Kevlin Henney on SOLID patterns.
#
# It underscores where I would like to go with this repo. Mainly, to start getting a better understanding on why some things are suggested to be done in a certain way, and what is the impact of the context of those suggestions.
#
# This talk:
# * puts design patterns in correct perspective
# * shares some of the lore on how they came about - some things are not what they seem to be!

# %%
YouTubeVideo('tMW08JkFrBA')

# %% [markdown]
# A talk by the father of the SOLID patterns himself.
#
# * How does OOP came about? (was it thought up by a bunch of CS professors giving this a lot of thought and discussion? you might be surprised!)
# * What is the main premise of OOP, what is the most valuable thing it gives us? Could it be one of the big three, Encapsulation, Inheritence or Polymorphism or is it something else?
# * Which of the big three we didn't have before OOP?

# %%
YouTubeVideo('t86v3N4OshQ', start=496)

# %% [markdown]
# To watch: a talk by Jim Weirich

# %%
YouTubeVideo('dKRbsE061u4')
